# %%
# train CNN ~ to arpa-e publication
# assign/determine number of cases, number of sensors per case, 
# list of locations to use for sensors for each case (random?, specified?)
# loop over training data files:
# from list, determine sensor cells and coords and scale, for each case j
# collect from training data files source info - coords, rate, for each case
# find Qsmin, Qsmax = min, max source leak rates over all cases
# scale leak rates Qs as Qscl=log(Qs/Qsmin)/log(Qsmax/Qsmin)
# read velocities & transform velocities (u,v,w) to (ur,utheta,w) to (speed,angle,w)
# pull out CH4 values for case.j; pull out CH4(time) for sensors.i,j
# mark time of first detect of CH4 > CH4min for each case j 
# for each sensor i,j find Cmax.i,j and time_max i,j for each case j
# Cmax = max(Cmax.i,j) = overall max concentration
# scaling. Csclmax=log(max(C,Cmin)/Cmin)/log(Cmax/Cmin)
# compute average velocity by integrating (u,v,w) back from time_max.i,j for delta.time
# delta.time ~ time for avg vel to cross domain to sensor.i,j 
# inputs: (x,y,z.sensor,Cmax,time_max).i,j
# outputs: (xsource,ysource,Qs).j
# run through NN (and try other algs); unscale
# test against subset of inputs,outputs pairs (not used for training).

# %%
#conda list -n myenv

# %%
#module load conda
#conda env create -f environment.yml
#conda activate seals

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import xarray as xr

# %%
from glob import glob

# %%
import os

# %%
import math

# %%
# convert u,v to wind speed, wind direction at a point

def polar(angle,speed,u,v,n):
    for i in range(0, n):
        speed[i]=np.sqrt(u[i]**2 + v[i]**2)
        angle[i]=math.degrees(math.atan2(v[i],u[i]))
    return angle,speed

# %%
# compute wind speed and direction for 2d field 

def polar2d(angle2d,speed2d,u2d,v2d,m):
    for i in range(0, m):
        for j in range(0, m):
            speed2d[i][j]=np.sqrt(u2d[i][j]**2 + v2d[i][j]**2)
            angle2d[i][j]=math.degrees(math.atan2(v2d[i][j],u2d[i][j]))
    return angle2d,speed2d

# %%
# find max concentration C in time series for a sensor

def findmaxC(CH4,times,n):
    maxC=0.
    time_maxC=0.
    ijkmax=0
    for i in range(0,n):
        if CH4[i] > maxC:
            maxC=CH4[i]
            time_maxC=times[i]
            ijkmax=i
    return maxC,time_maxC,ijkmax

# %%
# backtrack along velocity(t) path until x_length*factor has been traversed
# then return average velocity vector

def backtrack(ijk_start,u_sonic,v_sonic,dt,sensor_x,sensor_y,xmin,ymin):
    
    xn=sensor_x
    yn=sensor_y
    ijk=ijk_start
    ux_sum=0.
    vy_sum=0.
    
    while xn > xmin and yn > ymin and ijk > 0:
        
        u_bar=0.5*(u_sonic[ijk]+u_sonic[ijk-1])
        v_bar=0.5*(v_sonic[ijk]+v_sonic[ijk-1])
        xnm1=xn-dt*u_bar
        ynm1=yn-dt*v_bar
        ijk-=1
        ux_sum+=u_bar
        vy_sum+=v_bar
        xn=xnm1
        yn=ynm1
        
    avg_u=ux_sum/max(1,(ijk_start-ijk))
    avg_v=vy_sum/max(1,(ijk_start-ijk))
    
    return avg_u,avg_v

# %%
# read every nth file
# skip1 for skipping over subdirectories
# skip2 for skipping over files in each subdirectory
# eventually both will = 1

skip1=1
skip2=20

# %%
# define number of sensors and k,j,i locations
# also, threshhold value for concentrations C
# here just using 3 sensors to get started; 
# main coding is for arbitrary number of sensors

number_sensors=3
sensor_x_i=np.array([29,29,29])
sensor_y_i=np.array([15,22,29])
sensor_z_i=np.array([1,1,1])
sensor_x_scl=np.array([0.,0.,0.])
sensor_y_scl=np.array([0.,0.,0.])
sensor_z_scl=np.array([0.,0.,0.])
CH4_threshhold=1.e-7

# %%
# k,j,i for met sensor

# picking a point towards the left side
# just to have something to work with

sonic_loc=([1,15,5])

# %%
# factor indicates how much of domain width to use
# to stop backtracking. factor should be >= 0 but < ~0.5
# e.g., if factor = 0.25, then backtracking will track
# back from sensor location to x=0.25*xscale. Could 
# use other criterion such as location of sonic sensor

factor=0.25

# %%
# small number to keep log(CH4/CH4min) from blowing up if CH4=0

eps=1.0e-10

n_ins=0

# %%
# array for CH4 vs time at sensor locations

b_ts_ch4_sensor_i=[[],[],[]]

# %%
# path to Jeremy and Domingo's files

files_path='/glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23'
sub_dirs=os.listdir(files_path)
nsubs=len(sub_dirs)
sub_dirs
# Out:
# ['NBL', 'CBL', 'DC', 'SBL']

# %%
# create list of files in the subdirectories

files_l=[' ']*nsubs
dir_label=[' ']*nsubs
num_files=[0]*nsubs
total_files=0

for i in range(0,nsubs):
    dir_label[i]=files_path+'/'+sub_dirs[i]+'/'
    files_l[i]=os.listdir(dir_label[i])
    num_files[i]=len(files_l[i])
    total_files+=num_files[i]
    for j in range(0,num_files[i]):
        files_l[i][j]=dir_label[i]+files_l[i][j]

# %%
# define input and output vectors for NN

total_files_xns=total_files*number_sensors

v_input=np.empty(shape=[4*number_sensors+2,total_files_xns])
v_output=np.empty(shape=[4,total_files_xns])

v_input.shape
# Out:
# (14, 2088)

# %%
# initialize global CH4 and Q_leak max

CH4_max_global=0.
Q_leak_max_global=0.

# %%
from numpy import random
random.seed(42)

# %%
# beginning of loop over files to process
# will read in one at a time, pull out data
# add to NN input, output vectors
# after loop, need to scale C, Q and (u,v,w)

count=-1

for i in range(0,nsubs,skip1):
    for j in range(0,num_files[i],skip2):

        count+=1
            
        print('count=',count)
        
        b=xr.open_dataset(files_l[i][j])

        print('opened file=',files_l[i][j])

        # get dimensions of domain in each coord.
        
        xvals=b.xPos.isel(kDim=1,jDim=1).values
        nx=len(xvals)
        nx1=nx-1
        x_cellwidth=xvals[1]-xvals[0]

        yvals=b.yPos.isel(kDim=1,iDim=1).values
        ny=len(yvals)
        ny1=ny-1
        y_cellwidth=yvals[1]-yvals[0]

        zvals=b.zPos.isel(jDim=1,iDim=1).values
        nz=len(zvals)
        nz1=nz-1
        z_cellwidth=zvals[1]-zvals[0]

        # define ref point - lower left bottom corner
        
        xref=xvals[0]-x_cellwidth/2
        yref=yvals[0]-y_cellwidth/2
        zref=max(0.,zvals[0]-z_cellwidth/2.)

        # scales in each coord. = size of domain
        
        xscale=xvals[nx1]-xvals[0]+x_cellwidth
        yscale=yvals[ny1]-yvals[0]+y_cellwidth
        zscale=zvals[nz1]-zvals[0]+z_cellwidth

        # pull out time sequence, set reference time, time scale
        
        times=b.time.values
        ntimes=len(times)
        nt1=ntimes-1
        t_zero=times[0]
        time_scale=times[nt1]-t_zero
        dt=times[1]-times[0]   
        
# scale sensor locations

        for k in range(0,number_sensors):
            sensor_x_scl[k]=(sensor_x_i[k]-0.5)*x_cellwidth/xscale
            sensor_y_scl[k]=(sensor_y_i[k]-0.5)*x_cellwidth/yscale
            sensor_z_scl[k]=(sensor_z_i[k]-0.5)*z_cellwidth/zscale
            
        b.srcAuxScLocation
        
# get x,y,z and q for source

        q_source=b.srcAuxScMassSpecValue.values[0]
        x_source=b.srcAuxScLocation.values[0,0]
        y_source=b.srcAuxScLocation.values[0,1]
        z_source=b.srcAuxScLocation.values[0,2]
        
# scale source position variables

        x_source_scl=(x_source-xref)/xscale
        y_source_scl=(y_source-yref)/yscale
        z_source_scl=(z_source-zref)/zscale

        # track maximum leak rate, to use for scaling
        
        Q_leak_max_global=max(Q_leak_max_global,q_source)
        
        # pull out CH4 data (x,y,z,t)
        
        b.q_CH4
        
# pull out time series at sensor points

        for m in range(0,number_sensors):
            b_ts_ch4_sensor_i[m]=b.q_CH4.isel(kDim=sensor_z_i[m], jDim=sensor_y_i[m], iDim=sensor_x_i[m]).values

        # get u,v vs t at sonic location
        
        b_ts_u_sonic=b.u.isel(kDim=sonic_loc[0], jDim=sonic_loc[1], iDim=sonic_loc[2]).values
        b_ts_v_sonic=b.v.isel(kDim=sonic_loc[0], jDim=sonic_loc[1], iDim=sonic_loc[2]).values   
        b_ts_w_sonic=b.w.isel(kDim=sonic_loc[0], jDim=sonic_loc[1], iDim=sonic_loc[2]).values

        # convert u,v to angle,speed
        
        angle=np.zeros(ntimes)
        speed=np.zeros(ntimes)
        out=polar(angle,speed,b_ts_u_sonic,b_ts_v_sonic,ntimes)
        
        # make some plots
        
        if count == 0:
            
            # pull out a u field at early time for look-see
        
            b_2d_xy_u_t20sonic=b.u.isel(timeDim=20, kDim=sonic_loc[0]).values

            # pull out a v field at early time
        
            b_2d_xy_v_t20sonic=b.v.isel(timeDim=20, kDim=sonic_loc[0]).values

            # convert to angle,speed fields
        
            speed2d=np.zeros((nx1,ny1))
            angle2d=np.zeros((nx1,ny1))
            out=polar2d(angle2d,speed2d,b_2d_xy_u_t20sonic,b_2d_xy_v_t20sonic,nx1)
        
            # pull out x-y CH4 field at early time bottom layer to see plume
        
            b_2d_xy_qch4_t20sonic=b.q_CH4.isel(time=20, kDim=sonic_loc[0]).values
        
            # horizontal wind components vs time

            # make some plots to see what CH4 and winds v time looks like

            for mm in range(0,number_sensors):
                
                x=np.linspace(0,ntimes,ntimes)
                plt.xlabel('time')
                plt.ylabel('CH4 kg/kg')
                plt.title('at point i,j,k=sensors ')
                plt.plot(x,b_ts_ch4_sensor_i[mm])
                plt.show()
                
            plt.xlabel('time')
            plt.ylabel('u,v m/s')
            plt.title('at point i,j,k=sonic; blue=u,red=v')
            plt.plot(x,b_ts_u_sonic,'b',x,b_ts_v_sonic,'r')
            plt.show()
            
            plt.xlabel('time')
            plt.ylabel('vertical wind speed m/s')
            plt.title('at point i,j,k=sonic')
            plt.plot(x,b_ts_w_sonic)
            plt.show()
            
            # plot wind angle vs time
        
            plt.xlabel('time')
            plt.ylabel('wind angle')
            plt.title('angle: east=0, north=90, south=-90; i,j,k=sonic')
            plt.plot(x,angle)
            plt.show()
            
            # plot wind speed vs time
        
            plt.xlabel('time')
            plt.ylabel('wind speed m/s')
            plt.title('at point i,j,k=sonic')
            plt.plot(x,speed)
            plt.show()
            
            # contour plots of  winds on a plane early time
            
            fig1,ax2=plt.subplots(layout='constrained')
            xx=np.arange(0,30)
            yy=xx
            ax2.set_xlabel('x')
            ax2.set_ylabel('y')
            ax2.set_title('horizontal wind, x direction, m/s; t=20, k=sonic')
            cs=plt.contourf(b_2d_xy_u_t20sonic,cmap=plt.cm.jet)
            cbar=fig1.colorbar(cs)
            plt.show()
            
            fig1,ax2=plt.subplots(layout='constrained')
            xx=np.arange(0,30)
            yy=xx
            ax2.set_xlabel('x')
            ax2.set_ylabel('y')
            ax2.set_title('horizontal wind, y direction, m/s; t=20, k=2')
            cs=plt.contourf(b_2d_xy_v_t20sonic,cmap=plt.cm.jet)
            cbar=fig1.colorbar(cs)
            plt.show()
            
            # plot angle field
        
            fig1,ax2=plt.subplots(layout='constrained')
            xx=np.arange(0,30)
            yy=xx
            ax2.set_xlabel('x')
            ax2.set_ylabel('y')
            ax2.set_title('wind direction, degrees; t=20, k=sonic; 0=e, 90=n')
            cs=plt.contourf(angle2d,cmap=plt.cm.jet)
            cbar=fig1.colorbar(cs)
            plt.show()
            
            # plot speed field
        
            fig1,ax2=plt.subplots(layout='constrained')
            xx=np.arange(0,30)
            yy=xx
            ax2.set_xlabel('x')
            ax2.set_ylabel('y')
            ax2.set_title('wind speed  m/s; t=20, k=sonic')
            levels=[0.,1.5,3.0,4.5,6.0,7.5,9.0,10.5,12.]
            cs=plt.contourf(speed2d,levels,cmap=plt.cm.jet)
            cbar=fig1.colorbar(cs)
            plt.show()
            
            # plot CH4 field at early time
            
            fig1,ax2=plt.subplots(layout='constrained')
            xx=np.arange(0,30)
            yy=xx
            ax2.set_xlabel('x')
            ax2.set_ylabel('y')
            ax2.set_title('CH4 concentration, kg/kg; t=20, k=sonic')
            cs=plt.contourf(b_2d_xy_qch4_t20sonic,cmap=plt.cm.jet)
            cbar=fig1.colorbar(cs)
            plt.show()
        
        # initialize some vectors, arrays
        
        CH4max=np.empty(shape=[number_sensors])
        time_CH4max=np.empty(shape=[number_sensors])
        ijkmax=np.empty(shape=[number_sensors],dtype=int)
        avg_speed=np.empty(shape=[number_sensors])
        avg_angle=np.empty(shape=[number_sensors])
        CH4_assoc=np.empty(shape=[number_sensors,number_sensors])
        time_assoc=np.empty(shape=[number_sensors,number_sensors])

        # specify stopping points for backtracking
        
        min_x=factor*xscale
        min_y=factor*yscale

        # get max CH4 and corresponding time and ijk for each sensor location
        
        for ii in range(0,number_sensors):
            
            out=findmaxC(b_ts_ch4_sensor_i[ii],times,ntimes)
            
            CH4max[ii]=out[0]
            time_CH4max[ii]=out[1]
            ijkmax[ii]=out[2]

            # capture global max

            CH4_max_global=max(CH4_max_global,out[0])
            
            # find average velocity over backtrack interval
            # met sensor could be some distance from CH4 sensors
            # could include a lag time ~ time for winds at met to reach 
            # CH4 sensors
            
            uvavg=backtrack(ijkmax[ii],b_ts_u_sonic,b_ts_v_sonic,dt,
                sensor_x_scl[ii]*xscale,sensor_y_scl[ii]*yscale,min_x,min_y)
            ux_avg=uvavg[0]
            vy_avg=uvavg[1]
            
#            print('ii,ux_avg,vy_avg=',ii,ux_avg,vy_avg)
            
            avg_speed[ii]=np.sqrt(ux_avg**2 + vy_avg**2)
            avg_angle[ii]=math.degrees(math.atan2(vy_avg,ux_avg))

        # find concentrations at other sensors j != i corresponding to peak time at sensor i
     
        for ii in range(0,number_sensors):
            CH4_assoc[ii][ii]=CH4max[ii]
            time_assoc[ii][ii]=time_CH4max[ii]
            for jj in range(0,number_sensors):
                if jj != ii:
                    CH4_assoc[ii][jj]=b_ts_ch4_sensor_i[jj][ijkmax[ii]]
                    time_assoc[ii][jj]=times[ijkmax[ii]]
                  
        # fill in input vector
        # have number_sensors records for each case
        
        for ii in range(0,number_sensors):
            
            ncns=count*number_sensors+ii
            
            v_input[0][ncns]=avg_speed[ii]
            v_input[1][ncns]=avg_angle[ii]

            for pq in range(0,number_sensors):
                v_input[pq*4+2][ncns]=sensor_x_scl[pq]
                v_input[pq*4+3][ncns]=sensor_y_scl[pq]
                v_input[pq*4+4][ncns]=sensor_z_scl[pq]
                v_input[pq*4+5][ncns]=CH4_assoc[ii][pq]
            
#            print('i,v.input=',i,v_input[ncns])
                
        # save source info into learning target array
        
            v_output[0][ncns]=x_source_scl
            v_output[1][ncns]=y_source_scl
            v_output[2][ncns]=z_source_scl
            v_output[3][ncns]=q_source
        
        b.close()

# form scaling factors for CH4 and leak rate Q

Q_scale=Q_leak_max_global
CH4_scale=np.log10(CH4_max_global/CH4_threshhold)

print('CH4.max.global,Q.leak.max.global=',CH4_max_global,Q_leak_max_global)
print('CH4_scale,Q_scale=',CH4_scale,Q_scale)

# scale CH4 and Q_leak values

total_inputs=(count+1)*number_sensors

n_ins=4*number_sensors+2

for m in range(0,total_inputs):
    v_output[3][m]=v_output[3][m]/Q_scale

    print('m,v_output[3][m]=',m,v_output[3][m])
    
    for pq in range(0,number_sensors):
        v_input[pq*4+5][m]=np.log10(max(v_input[pq*4+5][m],CH4_threshhold)/CH4_threshhold)/CH4_scale

        print('pq,v_input[pq*4+5][m]==',pq,v_input[pq*4+5][m])
        
# set up NN (or other learning algorithm)

#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
#from tensorflow.keras import backend
#from keras_nlp.layers import TransformerDecoder, TransformerEncoder

# !pip install keras
# !pip install tensorflow
import tensorflow as tf
import keras.layers as layers
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential

model=Sequential()

print('after sequential')

#model.add(Input(shape=(total_inputs,n_ins)))
model.add(Input(shape=(n_ins,)))

# add input layer
model.add(Dense(activation = 'relu', units=64))

print('after first model.add.Dense')

#Add 1st hidden layer; how big should it be?
model.add(Dense(64, activation='relu'))

# Adding the output layer
model.add(Dense(4,activation='sigmoid'))


# Create optimizer with default learning rate
# Compile the model

print('at model.compile')

model.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

print('at model.summary')

print(model.summary())

X_train=np.empty(shape=[total_inputs,n_ins])
y_train=np.empty(shape=[total_inputs,4])

X_test=np.empty(shape=[total_inputs,n_ins])
y_test=np.empty(shape=[total_inputs,4])

print('n_ins,count+1,total_inputs=',n_ins,count+1,total_inputs)

# fill in X_train, y_train from v_input and v_output

for i in range(total_inputs):
    for j in range(n_ins):
        X_train[i][j]=v_input[j][i]
    for k in range(4):
        y_train[i][k]=v_output[k][i]

#    train the model

history=model.fit(X_train, y_train,validation_split=0.2,batch_size=(count+1)*3,epochs=25,verbose=1)

# Capturing learning history per epoch

hist  = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.head()

# Plotting loss function and accuracy vs epochs

plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train" , "valid") , loc ="upper right")
plt.show()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.plot(hist['accuracy'])
plt.plot(hist['val_accuracy'])
plt.legend(("train" , "valid") , loc ="upper right")
plt.show()

# apply model to training set to see how well/poorly true values are recovered

y_pred=model.predict(X_train)

# print true vs predicted for x,y locations and leak rate

print(' X.true,X.pred:Y.true,Y.pred:Q.true,Q.pred')
for i in range(total_inputs):
    e=[y_train[i][0],y_pred[i][0],y_train[i][1],y_pred[i][1],y_train[i][3],y_pred[i][3]]
    print([round(x,2) for x in e])
    
# scatterplot for recovered x,y source locations 
# leak rate recovery accuracy reflected in color of
# circles - color reflects error 

x_scttr=np.empty(shape=[total_inputs])
y_scttr=np.empty(shape=[total_inputs])
color=np.empty(shape=[total_inputs])

for i in range(0,total_inputs):
    x_scttr[i]=y_pred[i][0]
    y_scttr[i]=y_pred[i][1]
    color[i]=abs(v_output[3][i] - y_pred[i][3])

plt.axis([0.,1.,0.,1.])
plt.xlabel('X, scaled')
plt.ylabel('Y, scaled')
plt.title('recovered source locations and color-coded leak rate errors')
plt.scatter(sensor_x_scl,sensor_y_scl,marker='x')
plt.text(0.5,0.925,'X = sensor location')
plt.scatter(x_scttr,y_scttr,c=color,cmap='rainbow')
plt.colorbar()
plt.show()

              
#look at time series of CH4 and wind direction
#winds vary greatly; how well will velocity at one point
#correlate with ch4 at sensor points, and winds along
#path from source to sensor?
#can look at simple correlation; in arpa-e, we looked at
#average velocity over preceding delta.time interval, given
#by size of domain divided by average speed. Instead of 
#full time series, we used time of max CH4 at sensor, assuming
#that reflected a very direct path between source and sensor.

#Fourier (cosine) transform 'angle'
# is wind history at one point ~ as history at any other point? ergodicity?
# Out:
# count= 0
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/FE_NBL2m_Ug10_src1-8kg_a.3
# count= 1
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/NBL2m_Ug2p5_src1-8kg_a.7
# count= 2
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/NBL2m_Ug3p6_src1-8kg_b.6
# count= 3
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/FE_NBL2m_Ug5_src1-8kg_b.6
# count= 4
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/FE_NBL2m_Ug5_src10kg_b.3
# count= 5
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/FE_NBL2m_Ug5_src10kg_b.2
# count= 6
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/NBL2m_Ug7p5_src1-8kg_a.2
# count= 7
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/NBL/NBL2m_Ug3p6_src1-8kg_a.4
# count= 8
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug7p5_src1-8kg_b.5
# count= 9
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug5_src10kg_a.7
# count= 10
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug5_src1-8kg_b.1
# count= 11
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug2p5_src10kg_a.2
# count= 12
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug10_src1-8kg_a.7
# count= 13
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug5_src1-8kg_a.0
# count= 14
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug7p5_src10kg_a.4
# count= 15
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/CBL/CBL2m_Ug2p5_src1-8kg_b.6
# count= 16
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_05.1
# count= 17
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_02.5
# count= 18
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_09.0
# count= 19
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug15_src_9_10kg_hour_01.4
# count= 20
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug15_src_9_10kg_hour_11.6
# count= 21
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug15_src_9_10kg_hour_02.5
# count= 22
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_07.1
# count= 23
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_09.5
# count= 24
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug15_src_9_10kg_hour_09.5
# count= 25
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug7p5_src_9_10kg_hour_11.4
# count= 26
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/DC/DC_Ug15_src_9_10kg_hour_01.7
# count= 27
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug10_src10kg_b.0
# count= 28
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug7p5_src1-8kg_a.4
# count= 29
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug3p6_src1-8kg_b.7
# count= 30
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug2p5_src1-8kg_a.3
# count= 31
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug7p5_src10kg_a.1
# count= 32
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug10_src1-8kg_a.5
# count= 33
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug10_src10kg_a.1
# count= 34
# opened file= /glade/scratch/jsauer/ForPeople/ForCAMS/SET_10_12_23/SBL/SBL2m_Ug7p5_src10kg_a.3
# CH4.max.global,Q.leak.max.global= 0.00021373361 10.0
# CH4_scale,Q_scale= 3.3298728258618038 10.0
# m,v_output[3][m]= 0 0.4
# pq,v_input[pq*4+5][m]== 0 0.6351561492930166
# pq,v_input[pq*4+5][m]== 1 0.552590234996551
# pq,v_input[pq*4+5][m]== 2 0.34551539589219626
# m,v_output[3][m]= 1 0.4
# pq,v_input[pq*4+5][m]== 0 0.13245216815408706
# pq,v_input[pq*4+5][m]== 1 0.6841670334560805
# pq,v_input[pq*4+5][m]== 2 0.4874301513041367
# m,v_output[3][m]= 2 0.4
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5709546291524782
# pq,v_input[pq*4+5][m]== 2 0.6246901958544938
# m,v_output[3][m]= 3 0.8
# pq,v_input[pq*4+5][m]== 0 0.898610969180579
# pq,v_input[pq*4+5][m]== 1 0.8341560693191782
# pq,v_input[pq*4+5][m]== 2 0.3779360515162509
# m,v_output[3][m]= 4 0.8
# pq,v_input[pq*4+5][m]== 0 0.60610004998002
# pq,v_input[pq*4+5][m]== 1 0.9128698591383567
# pq,v_input[pq*4+5][m]== 2 0.5738372862984917
# m,v_output[3][m]= 5 0.8
# pq,v_input[pq*4+5][m]== 0 0.501008376775756
# pq,v_input[pq*4+5][m]== 1 0.8610944952158622
# pq,v_input[pq*4+5][m]== 2 0.7552438193376555
# m,v_output[3][m]= 6 0.7
# pq,v_input[pq*4+5][m]== 0 0.8216146890001065
# pq,v_input[pq*4+5][m]== 1 0.7825807750823176
# pq,v_input[pq*4+5][m]== 2 0.46246212076014614
# m,v_output[3][m]= 7 0.7
# pq,v_input[pq*4+5][m]== 0 0.5436335131353188
# pq,v_input[pq*4+5][m]== 1 0.8742395601075527
# pq,v_input[pq*4+5][m]== 2 0.6266687804375535
# m,v_output[3][m]= 8 0.7
# pq,v_input[pq*4+5][m]== 0 0.544640650311601
# pq,v_input[pq*4+5][m]== 1 0.7740090169576921
# pq,v_input[pq*4+5][m]== 2 0.7596773466760693
# m,v_output[3][m]= 9 0.7
# pq,v_input[pq*4+5][m]== 0 0.8925985824452992
# pq,v_input[pq*4+5][m]== 1 0.5288775825206792
# pq,v_input[pq*4+5][m]== 2 0.11031451004412694
# m,v_output[3][m]= 10 0.7
# pq,v_input[pq*4+5][m]== 0 0.39974573137518493
# pq,v_input[pq*4+5][m]== 1 0.8316263880610992
# pq,v_input[pq*4+5][m]== 2 0.5212873793163051
# m,v_output[3][m]= 11 0.7
# pq,v_input[pq*4+5][m]== 0 0.283857828710206
# pq,v_input[pq*4+5][m]== 1 0.7539311706304952
# pq,v_input[pq*4+5][m]== 2 0.6959647135111118
# m,v_output[3][m]= 12 1.0
# pq,v_input[pq*4+5][m]== 0 0.9770887373428647
# pq,v_input[pq*4+5][m]== 1 0.19283311609136855
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 13 1.0
# pq,v_input[pq*4+5][m]== 0 0.5758028600156342
# pq,v_input[pq*4+5][m]== 1 0.8817989345800049
# pq,v_input[pq*4+5][m]== 2 0.4327982909970064
# m,v_output[3][m]= 14 1.0
# pq,v_input[pq*4+5][m]== 0 0.22701900155580668
# pq,v_input[pq*4+5][m]== 1 0.8404204339716578
# pq,v_input[pq*4+5][m]== 2 0.7033562890488713
# m,v_output[3][m]= 15 1.0
# pq,v_input[pq*4+5][m]== 0 0.99133599169443
# pq,v_input[pq*4+5][m]== 1 0.5488223339181305
# pq,v_input[pq*4+5][m]== 2 0.1362492084517642
# m,v_output[3][m]= 16 1.0
# pq,v_input[pq*4+5][m]== 0 0.6524971823135679
# pq,v_input[pq*4+5][m]== 1 0.8601517150865585
# pq,v_input[pq*4+5][m]== 2 0.5341218738636404
# m,v_output[3][m]= 17 1.0
# pq,v_input[pq*4+5][m]== 0 0.44184506809657553
# pq,v_input[pq*4+5][m]== 1 0.7772237895082891
# pq,v_input[pq*4+5][m]== 2 0.7676471836979563
# m,v_output[3][m]= 18 0.3
# pq,v_input[pq*4+5][m]== 0 0.5655385432456987
# pq,v_input[pq*4+5][m]== 1 0.4163820762138734
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 19 0.3
# pq,v_input[pq*4+5][m]== 0 0.011012909028177989
# pq,v_input[pq*4+5][m]== 1 0.6638942077155178
# pq,v_input[pq*4+5][m]== 2 0.4769484578132558
# m,v_output[3][m]= 20 0.3
# pq,v_input[pq*4+5][m]== 0 0.09131178891587813
# pq,v_input[pq*4+5][m]== 1 0.6084870928536309
# pq,v_input[pq*4+5][m]== 2 0.6022351397717395
# m,v_output[3][m]= 21 0.5
# pq,v_input[pq*4+5][m]== 0 0.8505837718210043
# pq,v_input[pq*4+5][m]== 1 0.6980872862003655
# pq,v_input[pq*4+5][m]== 2 0.07388088003172619
# m,v_output[3][m]= 22 0.5
# pq,v_input[pq*4+5][m]== 0 0.3639457222709339
# pq,v_input[pq*4+5][m]== 1 0.8592023578303588
# pq,v_input[pq*4+5][m]== 2 0.5306906883938176
# m,v_output[3][m]= 23 0.5
# pq,v_input[pq*4+5][m]== 0 0.5707136789214597
# pq,v_input[pq*4+5][m]== 1 0.7391900765180074
# pq,v_input[pq*4+5][m]== 2 0.679364823796132
# m,v_output[3][m]= 24 0.6
# pq,v_input[pq*4+5][m]== 0 0.9036334717703052
# pq,v_input[pq*4+5][m]== 1 0.17901050390734133
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 25 0.6
# pq,v_input[pq*4+5][m]== 0 0.39911586046400543
# pq,v_input[pq*4+5][m]== 1 0.7485282007691161
# pq,v_input[pq*4+5][m]== 2 0.6425287919485395
# m,v_output[3][m]= 26 0.6
# pq,v_input[pq*4+5][m]== 0 0.29349747730336756
# pq,v_input[pq*4+5][m]== 1 0.6373828465215847
# pq,v_input[pq*4+5][m]== 2 0.6634819422208228
# m,v_output[3][m]= 27 1.0
# pq,v_input[pq*4+5][m]== 0 0.9817197255862058
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 28 1.0
# pq,v_input[pq*4+5][m]== 0 0.38990333764700064
# pq,v_input[pq*4+5][m]== 1 0.8105349593175969
# pq,v_input[pq*4+5][m]== 2 0.3777241717886963
# m,v_output[3][m]= 29 1.0
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5829754610630858
# pq,v_input[pq*4+5][m]== 2 0.7531441360868234
# m,v_output[3][m]= 30 0.2
# pq,v_input[pq*4+5][m]== 0 0.7651282335181929
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 31 0.2
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6098593873130655
# pq,v_input[pq*4+5][m]== 2 0.13314207920770554
# m,v_output[3][m]= 32 0.2
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.4031934525600247
# pq,v_input[pq*4+5][m]== 2 0.5674170137675748
# m,v_output[3][m]= 33 1.0
# pq,v_input[pq*4+5][m]== 0 0.9349041547921111
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.1341478813006217
# m,v_output[3][m]= 34 1.0
# pq,v_input[pq*4+5][m]== 0 0.35159032913179744
# pq,v_input[pq*4+5][m]== 1 0.8449207549564665
# pq,v_input[pq*4+5][m]== 2 0.8007882473275627
# m,v_output[3][m]= 35 1.0
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5647665610984556
# pq,v_input[pq*4+5][m]== 2 0.8453268702395749
# m,v_output[3][m]= 36 0.8
# pq,v_input[pq*4+5][m]== 0 0.9179437541450174
# pq,v_input[pq*4+5][m]== 1 0.5334581192167958
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 37 0.8
# pq,v_input[pq*4+5][m]== 0 0.5503406943299292
# pq,v_input[pq*4+5][m]== 1 0.7372947336885112
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 38 0.8
# pq,v_input[pq*4+5][m]== 0 0.05853277287705067
# pq,v_input[pq*4+5][m]== 1 0.6614355198366972
# pq,v_input[pq*4+5][m]== 2 0.6792868421016925
# m,v_output[3][m]= 39 0.1
# pq,v_input[pq*4+5][m]== 0 0.6874148942781487
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 40 0.1
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5419876164430825
# pq,v_input[pq*4+5][m]== 2 0.23327267289891426
# m,v_output[3][m]= 41 0.1
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.3796883249347985
# pq,v_input[pq*4+5][m]== 2 0.47027350046786076
# m,v_output[3][m]= 42 1.0
# pq,v_input[pq*4+5][m]== 0 1.0
# pq,v_input[pq*4+5][m]== 1 0.12721567943370796
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 43 1.0
# pq,v_input[pq*4+5][m]== 0 0.21148106507140263
# pq,v_input[pq*4+5][m]== 1 0.7978167213435926
# pq,v_input[pq*4+5][m]== 2 0.20112032168908028
# m,v_output[3][m]= 44 1.0
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6984926209498911
# pq,v_input[pq*4+5][m]== 2 0.7228000955557122
# m,v_output[3][m]= 45 0.7
# pq,v_input[pq*4+5][m]== 0 0.9629378784485788
# pq,v_input[pq*4+5][m]== 1 0.38456770878850954
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 46 0.7
# pq,v_input[pq*4+5][m]== 0 0.9097518949024117
# pq,v_input[pq*4+5][m]== 1 0.8350691634029602
# pq,v_input[pq*4+5][m]== 2 0.7744690873143111
# m,v_output[3][m]= 47 0.7
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5166332048116934
# pq,v_input[pq*4+5][m]== 2 0.8471954449930464
# m,v_output[3][m]= 48 0.2
# pq,v_input[pq*4+5][m]== 0 0.8665598853289573
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 49 0.2
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.7481513605034731
# pq,v_input[pq*4+5][m]== 2 0.25461546585525346
# m,v_output[3][m]= 50 0.2
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6313083460094591
# pq,v_input[pq*4+5][m]== 2 0.6989524464986504
# m,v_output[3][m]= 51 0.6
# pq,v_input[pq*4+5][m]== 0 0.9828035159751611
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 52 0.6
# pq,v_input[pq*4+5][m]== 0 0.719620929948314
# pq,v_input[pq*4+5][m]== 1 0.8021433712272159
# pq,v_input[pq*4+5][m]== 2 0.34438143405089827
# m,v_output[3][m]= 53 0.6
# pq,v_input[pq*4+5][m]== 0 0.7475168227293395
# pq,v_input[pq*4+5][m]== 1 0.7478045474517628
# pq,v_input[pq*4+5][m]== 2 0.37743810294273855
# m,v_output[3][m]= 54 0.1
# pq,v_input[pq*4+5][m]== 0 0.6224061653369045
# pq,v_input[pq*4+5][m]== 1 0.41104031094297994
# pq,v_input[pq*4+5][m]== 2 0.062441167273229486
# m,v_output[3][m]= 55 0.1
# pq,v_input[pq*4+5][m]== 0 0.14536865004046398
# pq,v_input[pq*4+5][m]== 1 0.6501408462718137
# pq,v_input[pq*4+5][m]== 2 0.44414849201879714
# m,v_output[3][m]= 56 0.1
# pq,v_input[pq*4+5][m]== 0 0.15053055542570556
# pq,v_input[pq*4+5][m]== 1 0.5553468494668692
# pq,v_input[pq*4+5][m]== 2 0.5672660702397168
# m,v_output[3][m]= 57 0.5
# pq,v_input[pq*4+5][m]== 0 0.8942289257983487
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 58 0.5
# pq,v_input[pq*4+5][m]== 0 0.4712131598471855
# pq,v_input[pq*4+5][m]== 1 0.6806059613432393
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 59 0.5
# pq,v_input[pq*4+5][m]== 0 0.5240200416409103
# pq,v_input[pq*4+5][m]== 1 0.5522721854686975
# pq,v_input[pq*4+5][m]== 2 0.09075660006475934
# m,v_output[3][m]= 60 0.7
# pq,v_input[pq*4+5][m]== 0 0.588660206866327
# pq,v_input[pq*4+5][m]== 1 0.7922711399126587
# pq,v_input[pq*4+5][m]== 2 0.705947489442575
# m,v_output[3][m]= 61 0.7
# pq,v_input[pq*4+5][m]== 0 0.23802136836951326
# pq,v_input[pq*4+5][m]== 1 0.8180474511575981
# pq,v_input[pq*4+5][m]== 2 0.7222604374987082
# m,v_output[3][m]= 62 0.7
# pq,v_input[pq*4+5][m]== 0 0.21778837224953315
# pq,v_input[pq*4+5][m]== 1 0.7251381435038398
# pq,v_input[pq*4+5][m]== 2 0.7698722083062266
# m,v_output[3][m]= 63 0.6
# pq,v_input[pq*4+5][m]== 0 0.9419002362806197
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 64 0.6
# pq,v_input[pq*4+5][m]== 0 0.6393884585358354
# pq,v_input[pq*4+5][m]== 1 0.7559917119651253
# pq,v_input[pq*4+5][m]== 2 0.37561928980416837
# m,v_output[3][m]= 65 0.6
# pq,v_input[pq*4+5][m]== 0 0.6393884585358354
# pq,v_input[pq*4+5][m]== 1 0.7559917119651253
# pq,v_input[pq*4+5][m]== 2 0.37561928980416837
# m,v_output[3][m]= 66 0.2
# pq,v_input[pq*4+5][m]== 0 0.8025229465768507
# pq,v_input[pq*4+5][m]== 1 0.4536925636556742
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 67 0.2
# pq,v_input[pq*4+5][m]== 0 0.22855376082521128
# pq,v_input[pq*4+5][m]== 1 0.7321962563642882
# pq,v_input[pq*4+5][m]== 2 0.4155457262523347
# m,v_output[3][m]= 68 0.2
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6013297558250921
# pq,v_input[pq*4+5][m]== 2 0.6581946374422442
# m,v_output[3][m]= 69 0.6
# pq,v_input[pq*4+5][m]== 0 0.8783673593729586
# pq,v_input[pq*4+5][m]== 1 0.6411956726467227
# pq,v_input[pq*4+5][m]== 2 0.019648527092175433
# m,v_output[3][m]= 70 0.6
# pq,v_input[pq*4+5][m]== 0 0.5782911083223051
# pq,v_input[pq*4+5][m]== 1 0.8517830876953099
# pq,v_input[pq*4+5][m]== 2 0.7078595682468468
# m,v_output[3][m]= 71 0.6
# pq,v_input[pq*4+5][m]== 0 0.23125990151496995
# pq,v_input[pq*4+5][m]== 1 0.7729632062502715
# pq,v_input[pq*4+5][m]== 2 0.8175731555992608
# m,v_output[3][m]= 72 0.6
# pq,v_input[pq*4+5][m]== 0 0.5354013961293482
# pq,v_input[pq*4+5][m]== 1 0.7326045494813601
# pq,v_input[pq*4+5][m]== 2 0.3555079578863769
# m,v_output[3][m]= 73 0.6
# pq,v_input[pq*4+5][m]== 0 0.13279387724415145
# pq,v_input[pq*4+5][m]== 1 0.7748672798084003
# pq,v_input[pq*4+5][m]== 2 0.6240075358245543
# m,v_output[3][m]= 74 0.6
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6139577133744739
# pq,v_input[pq*4+5][m]== 2 0.7476634921256976
# m,v_output[3][m]= 75 0.5
# pq,v_input[pq*4+5][m]== 0 0.6141251080023509
# pq,v_input[pq*4+5][m]== 1 0.725208906945799
# pq,v_input[pq*4+5][m]== 2 0.3496948847130942
# m,v_output[3][m]= 76 0.5
# pq,v_input[pq*4+5][m]== 0 0.10811800553978512
# pq,v_input[pq*4+5][m]== 1 0.8483554459424021
# pq,v_input[pq*4+5][m]== 2 0.6433132687366292
# m,v_output[3][m]= 77 0.5
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.7624769165872478
# pq,v_input[pq*4+5][m]== 2 0.762273647598653
# m,v_output[3][m]= 78 0.8
# pq,v_input[pq*4+5][m]== 0 0.9554187368856161
# pq,v_input[pq*4+5][m]== 1 0.0
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 79 0.8
# pq,v_input[pq*4+5][m]== 0 0.7143922110520845
# pq,v_input[pq*4+5][m]== 1 0.7422590856980468
# pq,v_input[pq*4+5][m]== 2 0.0
# m,v_output[3][m]= 80 0.8
# pq,v_input[pq*4+5][m]== 0 0.7021504078678147
# pq,v_input[pq*4+5][m]== 1 0.6396403265571097
# pq,v_input[pq*4+5][m]== 2 0.06241371999305705
# m,v_output[3][m]= 81 1.0
# pq,v_input[pq*4+5][m]== 0 0.5138566444289056
# pq,v_input[pq*4+5][m]== 1 0.6194216986239117
# pq,v_input[pq*4+5][m]== 2 0.5036445441836358
# m,v_output[3][m]= 82 1.0
# pq,v_input[pq*4+5][m]== 0 0.06113766922127351
# pq,v_input[pq*4+5][m]== 1 0.783244334873254
# pq,v_input[pq*4+5][m]== 2 0.6547599400972722
# m,v_output[3][m]= 83 1.0
# pq,v_input[pq*4+5][m]== 0 0.07579348060821176
# pq,v_input[pq*4+5][m]== 1 0.6237948849006304
# pq,v_input[pq*4+5][m]== 2 0.7595808048253259
# m,v_output[3][m]= 84 0.5
# pq,v_input[pq*4+5][m]== 0 0.31667649529757386
# pq,v_input[pq*4+5][m]== 1 0.6279226048698041
# pq,v_input[pq*4+5][m]== 2 0.5944712432920423
# m,v_output[3][m]= 85 0.5
# pq,v_input[pq*4+5][m]== 0 0.11362657993084009
# pq,v_input[pq*4+5][m]== 1 0.7273116459138288
# pq,v_input[pq*4+5][m]== 2 0.5392077930405904
# m,v_output[3][m]= 86 0.5
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.6183419331790247
# pq,v_input[pq*4+5][m]== 2 0.6920083976339336
# m,v_output[3][m]= 87 0.8
# pq,v_input[pq*4+5][m]== 0 0.13625219483014225
# pq,v_input[pq*4+5][m]== 1 0.7831676668383369
# pq,v_input[pq*4+5][m]== 2 0.8010475181716054
# m,v_output[3][m]= 88 0.8
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.8679341860129145
# pq,v_input[pq*4+5][m]== 2 0.7975356983698144
# m,v_output[3][m]= 89 0.8
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.651321790527539
# pq,v_input[pq*4+5][m]== 2 0.9015122834281044
# m,v_output[3][m]= 90 0.4
# pq,v_input[pq*4+5][m]== 0 0.1580918800534236
# pq,v_input[pq*4+5][m]== 1 0.5445769796317637
# pq,v_input[pq*4+5][m]== 2 0.7255635602599491
# m,v_output[3][m]= 91 0.4
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.829049575804487
# pq,v_input[pq*4+5][m]== 2 0.7757317786441056
# m,v_output[3][m]= 92 0.4
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.666997563232525
# pq,v_input[pq*4+5][m]== 2 0.836205269684185
# m,v_output[3][m]= 93 1.0
# pq,v_input[pq*4+5][m]== 0 0.5296037236873496
# pq,v_input[pq*4+5][m]== 1 0.7422936143590287
# pq,v_input[pq*4+5][m]== 2 0.5332416596488192
# m,v_output[3][m]= 94 1.0
# pq,v_input[pq*4+5][m]== 0 0.20750608880005608
# pq,v_input[pq*4+5][m]== 1 0.8011564256478954
# pq,v_input[pq*4+5][m]== 2 0.6521035793155563
# m,v_output[3][m]= 95 1.0
# pq,v_input[pq*4+5][m]== 0 0.09507821344390209
# pq,v_input[pq*4+5][m]== 1 0.7594979175566077
# pq,v_input[pq*4+5][m]== 2 0.785327027788091
# m,v_output[3][m]= 96 0.6
# pq,v_input[pq*4+5][m]== 0 0.28305040762681277
# pq,v_input[pq*4+5][m]== 1 0.6708389688478756
# pq,v_input[pq*4+5][m]== 2 0.6123440634680274
# m,v_output[3][m]= 97 0.6
# pq,v_input[pq*4+5][m]== 0 0.11486108584779381
# pq,v_input[pq*4+5][m]== 1 0.7021269221883992
# pq,v_input[pq*4+5][m]== 2 0.6159092220585203
# m,v_output[3][m]= 98 0.6
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.5423610639376325
# pq,v_input[pq*4+5][m]== 2 0.6658882370279368
# m,v_output[3][m]= 99 1.0
# pq,v_input[pq*4+5][m]== 0 0.4446405229285249
# pq,v_input[pq*4+5][m]== 1 0.708421094348738
# pq,v_input[pq*4+5][m]== 2 0.6204690362487554
# m,v_output[3][m]= 100 1.0
# pq,v_input[pq*4+5][m]== 0 0.0
# pq,v_input[pq*4+5][m]== 1 0.7677215996944914
# pq,v_input[pq*4+5][m]== 2 0.6572386185622374
# m,v_output[3][m]= 101 1.0
# pq,v_input[pq*4+5][m]== 0 0.21723159348720042
# pq,v_input[pq*4+5][m]== 1 0.6628252170328723
# pq,v_input[pq*4+5][m]== 2 0.7454931770701823
# m,v_output[3][m]= 102 1.0
# pq,v_input[pq*4+5][m]== 0 0.4213342322996762
# pq,v_input[pq*4+5][m]== 1 0.7037821662993652
# pq,v_input[pq*4+5][m]== 2 0.6088408701203061
# m,v_output[3][m]= 103 1.0
# pq,v_input[pq*4+5][m]== 0 0.11101822216467122
# pq,v_input[pq*4+5][m]== 1 0.8139221933597294
# pq,v_input[pq*4+5][m]== 2 0.7385243748813025
# m,v_output[3][m]= 104 1.0
# pq,v_input[pq*4+5][m]== 0 0.12002182820338306
# pq,v_input[pq*4+5][m]== 1 0.7414413768255984
# pq,v_input[pq*4+5][m]== 2 0.7824604383142869
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in ./.local/lib/python3.10/site-packages (2.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in ./.local/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.local/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.10/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: mpi4py>=3.1.1 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from h5py>=2.9.0->tensorflow) (3.1.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.local/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /glade/u/apps/opt/conda/envs/npl-2023b/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# 2023-11-28 10:56:20.350546: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-28 10:56:20.355075: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-28 10:56:20.394758: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 10:56:20.394804: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 10:56:20.396241: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 10:56:20.404284: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-28 10:56:20.405134: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-28 10:56:21.576345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# after sequential
# after first model.add.Dense
# at model.compile
# at model.summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                960
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 5380 (21.02 KB)
# Trainable params: 5380 (21.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-28 10:56:22.639271: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# None
# n_ins,count+1,total_inputs= 14 35 105
# Epoch 1/25
# 1/1 [==============================] - 1s 582ms/step - loss: 1.4079 - accuracy: 0.0000e+00 - val_loss: 0.9926 - val_accuracy: 0.1429
# Epoch 2/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8094 - accuracy: 0.2024 - val_loss: 0.6310 - val_accuracy: 0.1429
# Epoch 3/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6370 - accuracy: 0.1190 - val_loss: 0.5445 - val_accuracy: 0.5714
# Epoch 4/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5938 - accuracy: 0.2976 - val_loss: 0.5294 - val_accuracy: 0.6667
# Epoch 5/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5827 - accuracy: 0.3333 - val_loss: 0.5239 - val_accuracy: 0.7143
# Epoch 6/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5771 - accuracy: 0.3452 - val_loss: 0.5214 - val_accuracy: 0.7143
# Epoch 7/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5737 - accuracy: 0.3452 - val_loss: 0.5201 - val_accuracy: 0.7143
# Epoch 8/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5714 - accuracy: 0.3690 - val_loss: 0.5195 - val_accuracy: 0.7143
# Epoch 9/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5697 - accuracy: 0.3929 - val_loss: 0.5191 - val_accuracy: 0.7143
# Epoch 10/25
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5684 - accuracy: 0.3929 - val_loss: 0.5190 - val_accuracy: 0.7143
# Epoch 11/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5673 - accuracy: 0.3929 - val_loss: 0.5189 - val_accuracy: 0.7143
# Epoch 12/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5665 - accuracy: 0.4048 - val_loss: 0.5189 - val_accuracy: 0.7143
# Epoch 13/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5657 - accuracy: 0.4048 - val_loss: 0.5190 - val_accuracy: 0.7143
# Epoch 14/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5651 - accuracy: 0.4167 - val_loss: 0.5191 - val_accuracy: 0.7143
# Epoch 15/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5645 - accuracy: 0.4167 - val_loss: 0.5192 - val_accuracy: 0.7143
# Epoch 16/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5640 - accuracy: 0.4167 - val_loss: 0.5193 - val_accuracy: 0.7143
# Epoch 17/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5636 - accuracy: 0.4167 - val_loss: 0.5194 - val_accuracy: 0.7143
# Epoch 18/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5632 - accuracy: 0.4167 - val_loss: 0.5196 - val_accuracy: 0.7143
# Epoch 19/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5628 - accuracy: 0.4167 - val_loss: 0.5197 - val_accuracy: 0.7143
# Epoch 20/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5625 - accuracy: 0.4167 - val_loss: 0.5198 - val_accuracy: 0.7143
# Epoch 21/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5621 - accuracy: 0.4167 - val_loss: 0.5200 - val_accuracy: 0.7143
# Epoch 22/25
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5618 - accuracy: 0.4167 - val_loss: 0.5201 - val_accuracy: 0.7143
# Epoch 23/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5616 - accuracy: 0.4286 - val_loss: 0.5202 - val_accuracy: 0.7143
# Epoch 24/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5613 - accuracy: 0.4286 - val_loss: 0.5203 - val_accuracy: 0.7143
# Epoch 25/25
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5610 - accuracy: 0.4405 - val_loss: 0.5205 - val_accuracy: 0.7143
# 4/4 [==============================] - 0s 2ms/step
#  X.true,X.pred:Y.true,Y.pred:Q.true,Q.pred
# [0.52, 0.5, 0.52, 0.55, 0.4, 0.5]
# [0.52, 0.52, 0.52, 0.5, 0.4, 0.58]
# [0.52, 0.53, 0.52, 0.49, 0.4, 0.68]
# [0.52, 0.52, 0.52, 0.49, 0.8, 0.55]
# [0.52, 0.53, 0.52, 0.48, 0.8, 0.62]
# [0.52, 0.54, 0.52, 0.48, 0.8, 0.61]
# [0.52, 0.52, 0.52, 0.49, 0.7, 0.6]
# [0.52, 0.53, 0.52, 0.48, 0.7, 0.58]
# [0.52, 0.54, 0.52, 0.48, 0.7, 0.6]
# [0.52, 0.5, 0.52, 0.49, 0.7, 0.52]
# [0.52, 0.53, 0.52, 0.48, 0.7, 0.64]
# [0.52, 0.54, 0.52, 0.48, 0.7, 0.64]
# [0.52, 0.5, 0.52, 0.47, 1.0, 0.5]
# [0.52, 0.53, 0.52, 0.47, 1.0, 0.62]
# [0.52, 0.54, 0.52, 0.49, 1.0, 0.65]
# [0.52, 0.49, 0.52, 0.49, 1.0, 0.48]
# [0.52, 0.54, 0.52, 0.48, 1.0, 0.66]
# [0.52, 0.53, 0.52, 0.51, 1.0, 0.56]
# [0.52, 0.5, 0.52, 0.51, 0.3, 0.51]
# [0.52, 0.53, 0.52, 0.49, 0.3, 0.63]
# [0.52, 0.53, 0.52, 0.49, 0.3, 0.63]
# [0.52, 0.52, 0.52, 0.47, 0.5, 0.58]
# [0.52, 0.54, 0.52, 0.47, 0.5, 0.63]
# [0.52, 0.53, 0.52, 0.5, 0.5, 0.65]
# [0.52, 0.5, 0.52, 0.47, 0.6, 0.52]
# [0.52, 0.53, 0.52, 0.49, 0.6, 0.63]
# [0.52, 0.51, 0.52, 0.55, 0.6, 0.65]
# [0.52, 0.51, 0.52, 0.44, 1.0, 0.31]
# [0.52, 0.52, 0.52, 0.5, 1.0, 0.64]
# [0.52, 0.53, 0.52, 0.5, 1.0, 0.68]
# [0.52, 0.48, 0.52, 0.47, 0.2, 0.46]
# [0.52, 0.52, 0.52, 0.48, 0.2, 0.61]
# [0.52, 0.53, 0.52, 0.5, 0.2, 0.76]
# [0.52, 0.49, 0.52, 0.44, 1.0, 0.31]
# [0.52, 0.53, 0.52, 0.53, 1.0, 0.85]
# [0.52, 0.53, 0.52, 0.52, 1.0, 0.84]
# [0.52, 0.47, 0.52, 0.49, 0.8, 0.46]
# [0.52, 0.5, 0.52, 0.49, 0.8, 0.51]
# [0.52, 0.53, 0.52, 0.51, 0.8, 0.65]
# [0.52, 0.49, 0.52, 0.46, 0.1, 0.48]
# [0.52, 0.53, 0.52, 0.47, 0.1, 0.66]
# [0.52, 0.52, 0.52, 0.51, 0.1, 0.77]
# [0.52, 0.47, 0.52, 0.44, 1.0, 0.44]
# [0.52, 0.52, 0.52, 0.46, 1.0, 0.58]
# [0.52, 0.52, 0.52, 0.53, 1.0, 0.7]
# [0.52, 0.53, 0.52, 0.43, 0.7, 0.32]
# [0.52, 0.53, 0.52, 0.49, 0.7, 0.55]
# [0.52, 0.55, 0.52, 0.47, 0.7, 0.83]
# [0.51, 0.43, 0.52, 0.48, 0.2, 0.19]
# [0.51, 0.52, 0.52, 0.48, 0.2, 0.61]
# [0.51, 0.53, 0.52, 0.51, 0.2, 0.65]
# [0.52, 0.48, 0.51, 0.45, 0.6, 0.27]
# [0.52, 0.5, 0.51, 0.55, 0.6, 0.5]
# [0.52, 0.5, 0.51, 0.54, 0.6, 0.5]
# [0.51, 0.49, 0.51, 0.54, 0.1, 0.48]
# [0.51, 0.51, 0.51, 0.52, 0.1, 0.56]
# [0.51, 0.51, 0.51, 0.52, 0.1, 0.5]
# [0.52, 0.4, 0.52, 0.37, 0.5, 0.32]
# [0.52, 0.42, 0.52, 0.56, 0.5, 0.38]
# [0.52, 0.4, 0.52, 0.58, 0.5, 0.36]
# [0.51, 0.5, 0.51, 0.6, 0.7, 0.51]
# [0.51, 0.5, 0.51, 0.59, 0.7, 0.53]
# [0.51, 0.5, 0.51, 0.59, 0.7, 0.49]
# [0.52, 0.42, 0.51, 0.43, 0.6, 0.4]
# [0.52, 0.46, 0.51, 0.57, 0.6, 0.41]
# [0.52, 0.46, 0.51, 0.57, 0.6, 0.41]
# [0.51, 0.48, 0.52, 0.5, 0.2, 0.47]
# [0.51, 0.51, 0.52, 0.52, 0.2, 0.58]
# [0.51, 0.53, 0.52, 0.5, 0.2, 0.64]
# [0.52, 0.48, 0.51, 0.53, 0.6, 0.48]
# [0.52, 0.51, 0.51, 0.55, 0.6, 0.53]
# [0.52, 0.51, 0.51, 0.57, 0.6, 0.67]
# [0.52, 0.46, 0.51, 0.62, 0.6, 0.42]
# [0.52, 0.48, 0.51, 0.63, 0.6, 0.47]
# [0.52, 0.49, 0.51, 0.61, 0.6, 0.63]
# [0.52, 0.49, 0.52, 0.55, 0.5, 0.46]
# [0.52, 0.52, 0.52, 0.53, 0.5, 0.61]
# [0.52, 0.53, 0.52, 0.52, 0.5, 0.61]
# [0.51, 0.38, 0.52, 0.35, 0.8, 0.35]
# [0.51, 0.39, 0.52, 0.57, 0.8, 0.36]
# [0.51, 0.41, 0.52, 0.55, 0.8, 0.37]
# [0.52, 0.53, 0.52, 0.5, 1.0, 0.63]
# [0.52, 0.53, 0.52, 0.5, 1.0, 0.67]
# [0.52, 0.54, 0.52, 0.5, 1.0, 0.72]
# [0.52, 0.52, 0.52, 0.53, 0.5, 0.73]
# [0.52, 0.53, 0.52, 0.5, 0.5, 0.72]
# [0.52, 0.53, 0.52, 0.49, 0.5, 0.69]
# [0.52, 0.55, 0.52, 0.48, 0.8, 0.75]
# [0.52, 0.55, 0.52, 0.48, 0.8, 0.73]
# [0.52, 0.55, 0.52, 0.48, 0.8, 0.79]
# [0.52, 0.55, 0.52, 0.47, 0.4, 0.77]
# [0.52, 0.55, 0.52, 0.47, 0.4, 0.8]
# [0.52, 0.55, 0.52, 0.47, 0.4, 0.78]
# [0.52, 0.52, 0.52, 0.51, 1.0, 0.61]
# [0.52, 0.53, 0.52, 0.51, 1.0, 0.67]
# [0.52, 0.53, 0.52, 0.51, 1.0, 0.69]
# [0.52, 0.51, 0.52, 0.56, 0.6, 0.7]
# [0.52, 0.52, 0.52, 0.52, 0.6, 0.67]
# [0.52, 0.52, 0.52, 0.53, 0.6, 0.64]
# [0.52, 0.51, 0.52, 0.55, 1.0, 0.6]
# [0.52, 0.52, 0.52, 0.53, 1.0, 0.71]
# [0.52, 0.53, 0.52, 0.51, 1.0, 0.7]
# [0.52, 0.53, 0.52, 0.52, 1.0, 0.67]
# [0.52, 0.54, 0.52, 0.49, 1.0, 0.68]
# [0.52, 0.54, 0.52, 0.49, 1.0, 0.71]
